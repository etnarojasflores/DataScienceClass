# %% [markdown]
# <a href="https://colab.research.google.com/github/etnarojasflores/DataScienceClass/blob/main/Copia_de_EDA_TC2031.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Análisis exploratorio
# ## Tarea TC2031
#
#
# *   ¿Qué describen los datos?
# >Una encuesta aplicada a jóvenes
#
# * ¿Cuál es la demografía de grupo encuestado?
# * ¿Qué evalua la encuesta?
# * ¿Qué resultados tiene la encuesta?
# * ¿De qué tenemos más datos?
# * ¿Qué podemos hacer con esos datos?

# %%
# Importar librerias

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Leer el CSV
df = pd.read_csv('preferencias_respuestas.csv')
print(df.shape)
df.head()
# Out:
# (1010, 150)
#    Music  Slow songs or fast songs  ...  Village - town  House - block of flats
# 0    5.0                       3.0  ...         village          block of flats
# 1    4.0                       4.0  ...            city          block of flats
# 2    5.0                       5.0  ...            city          block of flats
# 3    5.0                       3.0  ...            city          house/bungalow
# 4    5.0                       3.0  ...         village          house/bungalow
#
# [5 rows x 150 columns]

# %%
variables = df.columns.tolist()

# %%
variables
# Out:
# ['Music',
#  'Slow songs or fast songs',
#  'Dance',
#  'Folk',
#  'Country',
#  'Classical music',
#  'Musical',
#  'Pop',
#  'Rock',
#  'Metal or Hardrock',
#  'Punk',
#  'Hiphop, Rap',
#  'Reggae, Ska',
#  'Swing, Jazz',
#  'Rock n roll',
#  'Alternative',
#  'Latino',
#  'Techno, Trance',
#  'Opera',
#  'Movies',
#  'Horror',
#  'Thriller',
#  'Comedy',
#  'Romantic',
#  'Sci-fi',
#  'War',
#  'Fantasy/Fairy tales',
#  'Animated',
#  'Documentary',
#  'Western',
#  'Action',
#  'History',
#  'Psychology',
#  'Politics',
#  'Mathematics',
#  'Physics',
#  'Internet',
#  'PC',
#  'Economy Management',
#  'Biology',
#  'Chemistry',
#  'Reading',
#  'Geography',
#  'Foreign languages',
#  'Medicine',
#  'Law',
#  'Cars',
#  'Art exhibitions',
#  'Religion',
#  'Countryside, outdoors',
#  'Dancing',
#  'Musical instruments',
#  'Writing',
#  'Passive sport',
#  'Active sport',
#  'Gardening',
#  'Celebrities',
#  'Shopping',
#  'Science and technology',
#  'Theatre',
# ...

# %%
dem_var = list(variables[-10:])
df[dem_var].hist(figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f16c1a894d0>,
# ...
#       dtype=object)

# %%
#Análisis de distribución por género

sns.displot(df, x='Age', kind='hist', hue='Gender', multiple='dodge',aspect=1.5)

# %%
df[variables[0:19]].hist(figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f16ac67b290>,
# ...
#       dtype=object)

# %%
music_corr = df[variables[0:19]].corr()
plt.figure(figsize=(20, 15))
sns.heatmap(music_corr, annot=True)
plt.show()

# %%
sns.countplot(x='Opera', data=df)

# %%
sns.countplot(x='Rock', data=df)

# %%
df[variables[19:31]].hist(figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f16ad696350>,
# ...
#       dtype=object)

# %%
viz_cont= sns.countplot(data=df, x='Education', hue='Gender')
viz_cont.set_xticklabels(viz_cont.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'college/bachelor degree'),
#  Text(0, 0, 'secondary school'),
#  Text(0, 0, 'primary school'),
#  Text(0, 0, 'masters degree'),
#  Text(0, 0, 'doctorate degree'),
#  Text(0, 0, 'currently a primary school pupil')]

# %%
viz_box= sns.boxplot(x='Metal or Hardrock',y='Age', hue='Gender', data=df, palette='rainbow')
viz_box.set_xticklabels(viz_box.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, '1.0'),
#  Text(0, 0, '2.0'),
#  Text(0, 0, '3.0'),
#  Text(0, 0, '4.0'),
#  Text(0, 0, '5.0')]

# %%
sns.boxplot(x='Gender',y='Weight',data=df,palette='rainbow')

# %%
dem_stat= df[['Gender','Education']].value_counts(normalize=True)
dem_stat
# Out:
# Gender  Education
# female  secondary school                    0.363908
# male    secondary school                    0.252243
# female  college/bachelor degree             0.122632
# male    college/bachelor degree             0.088734
# female  primary school                      0.053838
#         masters degree                      0.043868
# male    masters degree                      0.035892
#         primary school                      0.023928
# female  currently a primary school pupil    0.005982
# male    doctorate degree                    0.004985
#         currently a primary school pupil    0.003988
# dtype: float64

# %%
plt.figure(figsize=(20, 15))
dem_stat.plot.pie(autopct='%.1f%%')

# %%
# Ver cantidad de valores faltantes
df.isnull().sum().sort_values(ascending=False)[:15]
# Out:
# Weight                   20
# Height                   20
# Passive sport            15
# Chemistry                10
# Geography                 9
# Documentary               8
# Latino                    8
# Smoking                   8
# Punk                      8
# Theatre                   8
# Rock n roll               7
# Countryside, outdoors     7
# Gardening                 7
# Techno, Trance            7
# Alternative               7
# dtype: int64

# %% [markdown]
#
# ## Analítica descriptiva

# %%
# Estadistica descriptiva de variables que tienen valor numérico
df.describe()
# Out:
#              Music  Slow songs or fast songs  ...      Weight  Number of siblings
# count  1007.000000               1008.000000  ...  990.000000         1004.000000
# mean      4.731877                  3.328373  ...   66.405051            1.297809
# std       0.664049                  0.833931  ...   13.839561            1.013348
# min       1.000000                  1.000000  ...   41.000000            0.000000
# 25%       5.000000                  3.000000  ...   55.000000            1.000000
# 50%       5.000000                  3.000000  ...   64.000000            1.000000
# 75%       5.000000                  4.000000  ...   75.000000            2.000000
# max       5.000000                  5.000000  ...  165.000000           10.000000
#
# [8 rows x 139 columns]

# %%
# Estadistica descriptiva de variables categoricas
df.describe(exclude='number')
# Out:
#               Smoking         Alcohol  ... Village - town House - block of flats
# count            1002            1005  ...           1006                   1006
# unique              4               3  ...              2                      2
# top     tried smoking  social drinker  ...           city         block of flats
# freq              430             659  ...            707                    595
#
# [4 rows x 11 columns]

# %% [markdown]
# ## Ver *género* por rango escolar

# %%
# Ver la proporcion de sexo
df['Gender'].value_counts(normalize=True)
# Out:
# female    0.590637
# male      0.409363
# Name: Gender, dtype: float64

# %%
new_df = df[['Gender', 'Education']]
new_df
# Out:
#       Gender                Education
# 0     female  college/bachelor degree
# 1     female  college/bachelor degree
# 2     female         secondary school
# 3     female  college/bachelor degree
# 4     female         secondary school
# ...      ...                      ...
# 1005  female         secondary school
# 1006    male           masters degree
# 1007  female         secondary school
# 1008  female  college/bachelor degree
# 1009    male         secondary school
#
# [1010 rows x 2 columns]

# %%
count_sex_ed = new_df.groupby(['Education', 'Gender'])['Education'].count()
count_sex_ed
# Out:
# Education                         Gender
# college/bachelor degree           female    123
#                                   male       89
# currently a primary school pupil  female      6
#                                   male        4
# doctorate degree                  male        5
# masters degree                    female     44
#                                   male       36
# primary school                    female     54
#                                   male       24
# secondary school                  female    365
#                                   male      253
# Name: Education, dtype: int64

# %%
# Visualización de los datos
plt.figure(figsize=(20,12))
plt.title('Gender by Education Level')
count_sex_ed.plot.barh();

# %% [markdown]
# ### Ver intereses de mujeres en secundaria

# %%
data = (df['Education'] == 'secondary school') & (df['Gender'] == 'female')
fem_secondary = df[data]
print(fem_secondary.shape)
fem_secondary.head()
# Out:
# (365, 150)
#    Music  Slow songs or fast songs  ...  Village - town  House - block of flats
# 2    5.0                       5.0  ...            city          block of flats
# 4    5.0                       3.0  ...         village          house/bungalow
# 6    5.0                       5.0  ...         village          house/bungalow
# 8    5.0                       3.0  ...            city          house/bungalow
# 9    5.0                       3.0  ...            city          block of flats
#
# [5 rows x 150 columns]

# %%
fem_secondary = fem_secondary.copy()
fem_secondary = fem_secondary.drop(columns=['Smoking', 'Alcohol', 'Punctuality', 'Lying', 'Internet usage', 'Age', 'Height', 'Weight', 'Number of siblings', 'Gender',
       'Left - right handed', 'Education', 'Only child', 'Village - town',
       'House - block of flats'])
fem_secondary.loc['score_mean'] = fem_secondary.mean()

# %%
interests = fem_secondary.tail(1)
interests = interests.T.sort_values(by='score_mean',ascending=False)[:10]
interests
# Out:
#                        score_mean
# Music                    4.829670
# Movies                   4.657459
# Fun with friends         4.620879
# Comedy                   4.517808
# Compassion to animals    4.162983
# Empathy                  4.143251
# Borrowed stuff           4.068493
# Judgment calls           4.046703
# Internet                 4.035714
# Fantasy/Fairy tales      4.019178

# %%
interests.plot(kind='barh')
plt.title('Top 10 interests of secondary level females')
plt.show()
